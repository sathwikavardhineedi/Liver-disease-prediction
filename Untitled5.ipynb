# %%
# !pip install pandas numpy scikit-learn imbalanced-learn
import pandas as pd
import numpy as np
df = pd.read_csv("indian_liver_patient.csv")
df.head()
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
# Import necessary libraries

from imblearn.over_sampling import RandomOverSampler

# Step 1: Replace missing values with the mean of the column
df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].mean(), inplace=True)

# Separate features and target variable
X = df.drop(columns=['Dataset'])  # Dataset is the target column
y = df['Dataset']

# Convert categorical variables to numerical (e.g., Gender)
X = pd.get_dummies(X, drop_first=True)

# Step 2: Apply ROSE using RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

# Display the results
print("Original class distribution:", np.bincount(y))
print("Resampled class distribution:", np.bincount(y_resampled))

# Optional: Show a sample of the resampled data
print(X_resampled.head())
# Out:
# Original class distribution: [  0 416 167]
# Resampled class distribution: [  0 416 416]
#    Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65              0.7               0.1                   187
# 1   62             10.9               5.5                   699
# 2   62              7.3               4.1                   490
# 3   58              1.0               0.4                   182
# 4   72              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Gender_Male
# 0      3.3                        0.90        False
# 1      3.2                        0.74         True
# 2      3.3                        0.89         True
# 3      3.4                        1.00         True
# 4      2.4                        0.40         True

# %%
df.shape
# Out:
# (583, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def visualize_outliers_boxplot(df):
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    plt.figure(figsize=(15, 10))

    for i, column in enumerate(numeric_columns):
        plt.subplot(len(numeric_columns) // 3 + 1, 3, i + 1)
        sns.boxplot(x=df[column], color='lightblue')
        plt.title(f'Boxplot of {column}')

    plt.tight_layout()
    plt.show()

# Visualize outliers using box plots
visualize_outliers_boxplot(df)
print(f"Dataset size after outlier removal: {df.shape}")
# Out:
# Dataset size after outlier removal: (583, 11)

# %%
import pandas as pd

def replace_outliers_with_mean(df):
    # Loop through each column in the DataFrame
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)

        # Calculate IQR (Interquartile Range)
        IQR = Q3 - Q1

        # Define outliers as values outside 1.5*IQR from Q1 and Q3
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Calculate the mean of the column
        mean_value = df[column].mean()

        # Replace outliers with the mean value
        df[column] = df[column].apply(lambda x: mean_value if x < lower_bound or x > upper_bound else x)

    return df

# Apply the function to the entire DataFrame
df = replace_outliers_with_mean(df)

print(df)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female         0.700000          0.100000            187.000000
# 1     62    Male         3.298799          1.486106            290.576329
# 2     62    Male         3.298799          1.486106            290.576329
# 3     58    Male         1.000000          0.400000            182.000000
# 4     72    Male         3.900000          2.000000            195.000000
# ..   ...     ...              ...               ...                   ...
# 578   60    Male         0.500000          0.100000            290.576329
# 579   40    Male         0.600000          0.100000             98.000000
# 580   52    Male         0.800000          0.200000            245.000000
# 581   31    Male         1.300000          0.500000            184.000000
# 582   38    Male         1.000000          0.300000            216.000000
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16.0                        18.0             6.8
# 1                        64.0                       100.0             7.5
# 2                        60.0                        68.0             7.0
# 3                        14.0                        20.0             6.8
# 4                        27.0                        59.0             7.3
# ..                        ...                         ...             ...
# 578                      20.0                        34.0             5.9
# 579                      35.0                        31.0             6.0
# 580                      48.0                        49.0             6.4
# 581                      29.0                        32.0             6.8
# 582                      21.0                        24.0             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [583 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
# Required Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import RandomOverSampler


# Drop rows with missing values in 'Albumin_and_Globulin_Ratio'
df.dropna(subset=['Albumin_and_Globulin_Ratio'], inplace=True)

# Encode the 'Gender' column
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# Separate features and target variable
X = df.drop(columns=['Dataset'])
y = df['Dataset']

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply RandomOverSampler to handle class imbalance
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_scaled, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Define the autoencoder architecture
input_dim = X_train.shape[1]
encoding_dim = 5  # Dimension of the encoded representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation='relu')(input_layer)

# Decoder
decoder = Dense(input_dim, activation='linear')(encoder)

# Autoencoder model
autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=32,
                shuffle=True,
                validation_split=0.2,
                verbose=1)

# Encode the training and test data
encoder_model = Model(inputs=input_layer, outputs=encoder)
X_train_encoded = encoder_model.predict(X_train)
X_test_encoded = encoder_model.predict(X_test)

# Classification with encoded features (e.g., using Logistic Regression)
from sklearn.linear_model import LogisticRegression

# Train a simple classifier on the encoded data
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train_encoded, y_train)

# Predict and evaluate
y_pred = classifier.predict(X_test_encoded)
accuracy = accuracy_score(y_test, y_pred)

# Print the results
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3265 - val_loss: 1.3480
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1998 - val_loss: 1.2596
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1027 - val_loss: 1.1858
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0712 - val_loss: 1.1231
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0084 - val_loss: 1.0708
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9324 - val_loss: 1.0249
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9183 - val_loss: 0.9841
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8831 - val_loss: 0.9479
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8038 - val_loss: 0.9151
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8136 - val_loss: 0.8829
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7767 - val_loss: 0.8540
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7590 - val_loss: 0.8274
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7464 - val_loss: 0.8018
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6924 - val_loss: 0.7795
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6844 - val_loss: 0.7576
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6773 - val_loss: 0.7372
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6522 - val_loss: 0.7184
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6325 - val_loss: 0.7000
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6041 - val_loss: 0.6830
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5894 - val_loss: 0.6670
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5754 - val_loss: 0.6523
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5701 - val_loss: 0.6381
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5449 - val_loss: 0.6252
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5086 - val_loss: 0.6132
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5088 - val_loss: 0.6013
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5053 - val_loss: 0.5904
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5190 - val_loss: 0.5804
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4873 - val_loss: 0.5713
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4985 - val_loss: 0.5625
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5003 - val_loss: 0.5544
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4584 - val_loss: 0.5466
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4425 - val_loss: 0.5394
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4733 - val_loss: 0.5323
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4162 - val_loss: 0.5259
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4361 - val_loss: 0.5200
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4083 - val_loss: 0.5141
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4718 - val_loss: 0.5085
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4230 - val_loss: 0.5033
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4076 - val_loss: 0.4985
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4024 - val_loss: 0.4939
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3883 - val_loss: 0.4896
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4080 - val_loss: 0.4853
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3848 - val_loss: 0.4813
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3896 - val_loss: 0.4775
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3986 - val_loss: 0.4735
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3871 - val_loss: 0.4699
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3933 - val_loss: 0.4662
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3828 - val_loss: 0.4632
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3738 - val_loss: 0.4598
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3591 - val_loss: 0.4567
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.72
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.72      0.63      0.67        75
#            2       0.73      0.80      0.76        92
#
#     accuracy                           0.72       167
#    macro avg       0.72      0.72      0.72       167
# weighted avg       0.72      0.72      0.72       167
